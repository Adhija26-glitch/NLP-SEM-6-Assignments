# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet as wn

# %%
word = "good"

# %%
hyponyms = set()

for synset in wn.synsets(word):
    for hyponym in synset.hyponyms():
        hyponyms.add(hyponym.name())

print("\nHyponyms:")
print(hyponyms)
# Out:
# Hyponyms:
# {'fungible.n.01', 'export.n.01', 'worthiness.n.01', 'shopping.n.02', 'salvage.n.01', 'saintliness.n.01', 'basic.n.02', 'virtue.n.04', 'entrant.n.01', 'drygoods.n.01', 'summum_bonum.n.01', 'kindness.n.01', 'better.n.04', 'consumer_goods.n.01', 'desirability.n.01', 'merchandise.n.01', 'virtue.n.01', 'middling.n.01', 'future.n.03', 'beneficence.n.02', 'worldly_possession.n.01', 'sporting_goods.n.01', 'import.n.01', 'benefit.n.02', 'better.n.01', 'wisdom.n.04', 'optimum.n.01', 'common_good.n.01', 'benignity.n.01', 'fancy_goods.n.01'}

# %%
hypernyms = set()

for synset in wn.synsets(word):
    for hypernym in synset.hypernyms():
        hypernyms.add(hypernym.name())

print("\nHypernyms:")
print(hypernyms)
# Out:
# Hypernyms:
# {'morality.n.01', 'quality.n.01', 'advantage.n.01', 'artifact.n.01'}

# %%
synonyms = set()

for synset in wn.synsets(word):
    for lemma in synset.lemmas():
        synonyms.add(lemma.name())

print("Synonyms:")
print(synonyms)
# Out:
# Synonyms:
# {'secure', 'soundly', 'upright', 'serious', 'good', 'respectable', 'well', 'in_effect', 'sound', 'salutary', 'proficient', 'right', 'estimable', 'dear', 'unspoiled', 'full', 'undecomposed', 'trade_good', 'effective', 'thoroughly', 'adept', 'unspoilt', 'skillful', 'commodity', 'dependable', 'expert', 'skilful', 'ripe', 'beneficial', 'practiced', 'near', 'safe', 'in_force', 'honest', 'honorable', 'just', 'goodness'}

# %%
antonyms = set()

for synset in wn.synsets(word):
    for lemma in synset.lemmas():
        if lemma.antonyms():
            antonyms.add(lemma.antonyms()[0].name())

print("\nAntonyms:")
print(antonyms)
# Out:
# Antonyms:
# {'bad', 'evil', 'badness', 'evilness', 'ill'}

# %%
word = "cool"
synonyms = set()

for synset in wn.synsets(word):
    for lemma in synset.lemmas():
        synonyms.add(lemma.name())

print("Synonyms:")
print(synonyms)
# Out:
# Synonyms:
# {'cool_down', 'sang-froid', 'aplomb', 'chill', 'assuredness', 'coolheaded', 'nerveless', 'poise', 'cool', 'cool_off'}

# %%
antonyms = set()

for synset in wn.synsets(word):
    for lemma in synset.lemmas():
        if lemma.antonyms():
            antonyms.add(lemma.antonyms()[0].name())

print("\nAntonyms:")
print(antonyms)
# Out:
# Antonyms:
# {'heat', 'warm'}

# %%
hypernyms = set()

for synset in wn.synsets(word):
    for hypernym in synset.hypernyms():
        hypernyms.add(hypernym.name())

print("\nHypernyms:")
print(hypernyms)
# Out:
# Hypernyms:
# {'change.v.01', 'composure.n.01', 'change_state.v.01', 'coldness.n.03', 'change.v.02'}

# %%
hyponyms = set()

for synset in wn.synsets(word):
    for hyponym in synset.hyponyms():
        hyponyms.add(hyponym.name())

print("\nHyponyms:")
print(hyponyms)
# Out:
# Hyponyms:
# {'refrigerate.v.02', 'quench.v.06', 'ice.v.03'}
