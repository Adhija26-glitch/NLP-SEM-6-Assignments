# %%
# !pip install -q nltk

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk import pos_tag, FreqDist

text = """Natural Language Processing is a powerful tool.
It helps machines understand human language.
NLP is widely used in chatbots, translation systems, and text analysis."""

sentences = sent_tokenize(text)
words = word_tokenize(text.lower())

stop_words = set(stopwords.words("english"))
filtered_words = [w for w in words if w.isalpha() and w not in stop_words]

pos_tags = pos_tag(filtered_words)

freq_dist = FreqDist(filtered_words)

print("Sentences:")
print(sentences)

print("\nTokens:")
print(words)

print("\nFiltered Words:")
print(filtered_words)

print("\nPOS Tags:")
print(pos_tags)

print("\nTop 5 Frequent Words:")
print(freq_dist.most_common(5))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Sentences:
# ['Natural Language Processing is a powerful tool.', 'It helps machines understand human language.', 'NLP is widely used in chatbots, translation systems, and text analysis.']
#
# Tokens:
# ['natural', 'language', 'processing', 'is', 'a', 'powerful', 'tool', '.', 'it', 'helps', 'machines', 'understand', 'human', 'language', '.', 'nlp', 'is', 'widely', 'used', 'in', 'chatbots', ',', 'translation', 'systems', ',', 'and', 'text', 'analysis', '.']
#
# Filtered Words:
# ['natural', 'language', 'processing', 'powerful', 'tool', 'helps', 'machines', 'understand', 'human', 'language', 'nlp', 'widely', 'used', 'chatbots', 'translation', 'systems', 'text', 'analysis']
#
# POS Tags:
# [('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('powerful', 'JJ'), ('tool', 'NN'), ('helps', 'VBZ'), ('machines', 'NNS'), ('understand', 'JJ'), ('human', 'JJ'), ('language', 'NN'), ('nlp', 'NN'), ('widely', 'RB'), ('used', 'VBN'), ('chatbots', 'JJ'), ('translation', 'NN'), ('systems', 'NNS'), ('text', 'JJ'), ('analysis', 'NN')]
#
# Top 5 Frequent Words:
# [('language', 2), ('natural', 1), ('processing', 1), ('powerful', 1), ('tool', 1)]
